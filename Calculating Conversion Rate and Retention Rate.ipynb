# %%
import pandas as pd

# %%
# import the data

marketing=pd.read_csv("marketing.csv")

# To return the first n rows for the object based on position. 
# It is useful for quickly testing if your object has the right type of data in it.
marketing.head(n=15)
# Out:
#        user_id date_served marketing_channel          variant converted  \
# 0   a100000029      1/1/18         House Ads  personalization      True
# 1   a100000030      1/1/18         House Ads  personalization      True
# 2   a100000031      1/1/18         House Ads  personalization      True
# 3   a100000032      1/1/18         House Ads  personalization      True
# 4   a100000033      1/1/18         House Ads  personalization      True
# 5   a100000034      1/1/18         House Ads  personalization      True
# 6   a100000035      1/1/18         House Ads  personalization      True
# 7   a100000036      1/1/18         House Ads  personalization      True
# 8   a100000037      1/1/18         House Ads  personalization      True
# 9   a100000038      1/1/18         House Ads  personalization      True
# 10  a100000039      1/1/18         House Ads  personalization      True
# 11  a100000040      1/1/18         House Ads  personalization      True
# ...

# %%
# Check how many columns and rows are in the data

marketing.shape
# Out:
# (10037, 12)

# %%
# Use summary statistics to describe the data

marketing.describe()
# Out:
#            user_id date_served marketing_channel  variant converted  \
# count        10037       10021             10022    10037     10022
# unique        7309          31                 5        2         2
# top     a100000882     1/15/18         House Ads  control     False
# freq            12         789              4733     5091      8946
#
#        language_displayed language_preferred    age_group date_subscribed  \
# count               10037              10037        10037            1856
# unique                  4                  4            7              31
# top               English            English  19-24 years         1/16/18
# freq                 9793               9275         1682             163
#
#        date_canceled subscribing_channel is_retained
# count            577                1856        1856
# unique           115                   5           2
# top           4/2/18           Instagram        True
# ...

# %% [markdown]
# ![sss.PNG](attachment:sss.PNG)

# %%
# Calculate the Total number of people who we market to

total = marketing['user_id'].nunique()
print('Total number of people who we market to:',total)
# Out:
# Total number of people who we market to: 7309

# %%
# Calculate the number of people who subscribed or Number of people who convert

subscribers = marketing[marketing["converted"] == True]\
['user_id'].nunique()

print('Number of people who convert:',subscribers)
# Out:
# Number of people who convert: 1015

# %%
# Calculate the conversion rate

conversion_rate = subscribers / total
print('Conversion Rate:',round(conversion_rate*100, 2), "%")
# Out:
# Conversion Rate: 13.89 %

# %% [markdown]
# ![adfaf.PNG](attachment:adfaf.PNG)

# %%
# Calculate the number of subscribers

total_subscribers = marketing[marketing["converted"] == True]\
['user_id'].nunique()

print('total_subscribers:',total_subscribers)
# Out:
# total_subscribers: 1015

# %%
# Calculate the number of people who remained subscribed

retained = marketing[marketing['is_retained'] == True]\
['user_id'].nunique()

print('Number of People Retained:',retained)
# Out:
# Number of People Retained: 678

# %%
# Calculate the retention rate

retention_rate = retained/total_subscribers
print('Retention Rate:',round(retention_rate*100, 2), "%")
# Out:
# Retention Rate: 66.8 %
